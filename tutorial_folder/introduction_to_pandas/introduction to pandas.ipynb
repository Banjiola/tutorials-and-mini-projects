# %% [markdown]
# ## Introduction to Pandas

# %%
pip install pandas
# Out:
# ...
#
# ...

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.2.2

# %%
#example of pd.series
age = [21, 24, 27, 44, 52]
series = pd.Series(age)

print(series)
# Out:
# 0    21
# 1    24
# 2    27
# 3    44
# 4    52
# dtype: int64

# %%
#example of dataframe
data = {
    "Age": [21, 24, 27, 44, 52],
    "Salary": [52000, 58000, 71000, 85000, 920000]
}

dataframe = pd.DataFrame(data)
print(dataframe)
# Out:
#    Age  Salary
# 0   21   52000
# 1   24   58000
# 2   27   71000
# 3   44   85000
# 4   52  920000

# %%
#reading csv files
file_path = r"c:\Users\banji\Downloads\archive (1)\HR_comma_sep.csv"
df = pd.read_csv(file_path)
print(df.head())
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# ...

# %%
#reading tab separated values file stored as csv
file_path = r"C:\Users\banji\Downloads\employee_data.csv"
df = pd.read_csv(file_path, sep ='\t') #here we use the sep ='\t'
print(df.head())
# Out:
#       Name  Age  Salary Department
# 0    James   28   48403  Marketing
# 1    David   48  122292         HR
# 2    Sarah   33  125067         IT
# 3     John   60   53195         HR
# 4  Michael   32   57330         HR

# %%
#reading excel files
file_path = r"C:\Users\banji\OneDrive\Documents\NGX formely NSE.xlsx"
df = pd.read_excel(file_path) 
(df.head())
# Out:
#                                 Company      Ticker              Sector  \
# 0               ABBEY MORTGAGE BANK PLC    ABBEYBDS  FINANCIAL SERVICES
# 1                    ACADEMY PRESS PLC.     ACADEMY            SERVICES
# 2             ACCESS HOLDINGS PLC [CG+]  ACCESSCORP  FINANCIAL SERVICES
# 3           AFRICA PRUDENTIAL PLC [CG+]    AFRIPRUD  FINANCIAL SERVICES
# 4  AFRICAN ALLIANCE INSURANCE PLC [MRF]   AFRINSURE  FINANCIAL SERVICES
#
#            Date Listed    Date Incorporated  Unnamed: 5  \
# 0                    -  1991-08-26 00:00:00         NaN
# 1  1965-06-15 00:00:00  1964-07-28 00:00:00         NaN
# 2  2022-03-28 00:00:00  2021-02-10 00:00:00         NaN
# 3  2013-11-01 00:00:00  2006-03-23 00:00:00         NaN
# 4  2009-09-17 00:00:00  1960-05-06 00:00:00         NaN
#
#                                           Unnamed: 6
# 0                                                NaN
# 1  151 companies. Dangote and Transcorp have teo ...
# ...

# %%
#loading dataset
file_path = r"C:\Users\banji\Downloads\Melbourne_housing_FULL.csv\Melbourne_housing_FULL.csv"
df = pd.read_csv(file_path)

#basic data exploration
df.head() #displays first five rows
#similarly df.tail() will display last five rows
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %%
df.tail() #displays last 5 rows
# Out:
#            Suburb           Address  Rooms Type      Price Method  \
# 34852  Yarraville       13 Burns St      4    h  1480000.0     PI
# 34853  Yarraville     29A Murray St      2    h   888000.0     SP
# 34854  Yarraville    147A Severn St      2    t   705000.0      S
# 34855  Yarraville  12/37 Stephen St      3    h  1140000.0     SP
# 34856  Yarraville  3 Tarrengower St      2    h  1020000.0     PI
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 34852            Jas  24/02/2018       6.3    3013.0  ...       1.0  3.0
# 34853        Sweeney  24/02/2018       6.3    3013.0  ...       2.0  1.0
# 34854            Jas  24/02/2018       6.3    3013.0  ...       1.0  2.0
# 34855  hockingstuart  24/02/2018       6.3    3013.0  ...       NaN  NaN
# 34856             RW  24/02/2018       6.3    3013.0  ...       1.0  0.0
#
#        Landsize  BuildingArea  YearBuilt               CouncilArea Lattitude  \
# ...

# %%
print(df.index)
print(df.columns)
# Out:
# RangeIndex(start=0, stop=34857, step=1)
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34857 entries, 0 to 34856
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         34857 non-null  object
#  1   Address        34857 non-null  object
#  2   Rooms          34857 non-null  int64
#  3   Type           34857 non-null  object
#  4   Price          27247 non-null  float64
#  5   Method         34857 non-null  object
#  6   SellerG        34857 non-null  object
#  7   Date           34857 non-null  object
#  8   Distance       34856 non-null  float64
#  9   Postcode       34856 non-null  float64
#  10  Bedroom2       26640 non-null  float64
#  11  Bathroom       26631 non-null  float64
#  12  Car            26129 non-null  float64
#  13  Landsize       23047 non-null  float64
#  14  BuildingArea   13742 non-null  float64
#  15  YearBuilt      15551 non-null  float64
#  16  CouncilArea    34854 non-null  object
# ...

# %%
print(df.describe())
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  34857.000000  2.724700e+04  34856.000000  34856.000000  26640.000000
# mean       3.031012  1.050173e+06     11.184929   3116.062859      3.084647
# std        0.969933  6.414671e+05      6.788892    109.023903      0.980690
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.350000e+05      6.400000   3051.000000      2.000000
# 50%        3.000000  8.700000e+05     10.300000   3103.000000      3.000000
# 75%        4.000000  1.295000e+06     14.000000   3156.000000      4.000000
# max       16.000000  1.120000e+07     48.100000   3978.000000     30.000000
#
#            Bathroom           Car       Landsize  BuildingArea     YearBuilt  \
# count  26631.000000  26129.000000   23047.000000   13742.00000  15551.000000
# mean       1.624798      1.728845     593.598993     160.25640   1965.289885
# ...

# %%
#data cleaning and manuipulation
print("Number of null entries")
print(df.isna().sum())
print()
print("Number of duplicate entries")
print(df.duplicated().sum())
# Out:
# Number of null entries
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# YearBuilt        19306
# CouncilArea          3
# Lattitude         7976
# Longtitude        7976
# Regionname           3
# Propertycount        3
# dtype: int64
#
# Number of duplicate entries
# 1

# %%
##Selecting columns
df[["Address","Price"]] #take note that the keys are case sensitive
# Out:
#                   Address      Price
# 0           68 Studley St        NaN
# 1            85 Turner St  1480000.0
# 2         25 Bloomburg St  1035000.0
# 3      18/659 Victoria St        NaN
# 4            5 Charles St  1465000.0
# ...                   ...        ...
# 34852         13 Burns St  1480000.0
# 34853       29A Murray St   888000.0
# 34854      147A Severn St   705000.0
# 34855    12/37 Stephen St  1140000.0
# 34856    3 Tarrengower St  1020000.0
#
# [34857 rows x 2 columns]

# %%
#df.loc[0] .In this example our index are numbers and don't have names. 
# In the case where the index is a string then replace 0 with the name.
df.iloc[0] #returns the row in index 1
# Out:
# Suburb                      Abbotsford
# Address                  68 Studley St
# Rooms                                2
# Type                                 h
# Price                              NaN
# Method                              SS
# SellerG                         Jellis
# Date                         3/09/2016
# Distance                           2.5
# Postcode                        3067.0
# Bedroom2                           2.0
# Bathroom                           1.0
# Car                                1.0
# Landsize                         126.0
# BuildingArea                       NaN
# YearBuilt                          NaN
# CouncilArea         Yarra City Council
# Lattitude                     -37.8014
# Longtitude                    144.9958
# Regionname       Northern Metropolitan
# Propertycount                   4019.0
# Name: 0, dtype: object

# %%
df.iloc[:,0] # This returns the column in index 0 which is the first column
# Out:
# 0        Abbotsford
# 1        Abbotsford
# 2        Abbotsford
# 3        Abbotsford
# 4        Abbotsford
#             ...
# 34852    Yarraville
# 34853    Yarraville
# 34854    Yarraville
# 34855    Yarraville
# 34856    Yarraville
# Name: Suburb, Length: 34857, dtype: object

# %%
df.isnull().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# YearBuilt        19306
# CouncilArea          3
# Lattitude         7976
# Longtitude        7976
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
df.Price
# Out:
# 0              NaN
# 1        1480000.0
# 2        1035000.0
# 3              NaN
# 4        1465000.0
#            ...
# 34852    1480000.0
# 34853     888000.0
# 34854     705000.0
# 34855    1140000.0
# 34856    1020000.0
# Name: Price, Length: 34857, dtype: float64

# %%
#we can fill the null entries in price with the average price
print(df["Price"]) #without filling null
df["Price"].fillna(df["Price"].mean()) #after filling null
# Out:
# 0              NaN
# 1        1480000.0
# 2        1035000.0
# 3              NaN
# 4        1465000.0
#            ...
# 34852    1480000.0
# 34853     888000.0
# 34854     705000.0
# 34855    1140000.0
# 34856    1020000.0
# Name: Price, Length: 34857, dtype: float64
# 0        1.050173e+06
# 1        1.480000e+06
# 2        1.035000e+06
# 3        1.050173e+06
# 4        1.465000e+06
#              ...
# 34852    1.480000e+06
# 34853    8.880000e+05
# 34854    7.050000e+05
# 34855    1.140000e+06
# 34856    1.020000e+06
# Name: Price, Length: 34857, dtype: float64

# %%
df.sort_values(by= 'Suburb', ascending= True) #this sort the columns by suburb in descending format
# Out:
#            Suburb              Address  Rooms Type      Price Method  \
# 0      Abbotsford        68 Studley St      2    h        NaN     SS
# 22160  Abbotsford   36/659 Victoria St      2    u        NaN     PI
# 22159  Abbotsford   604/88 Trenerry Cr      2    u   683000.0     SP
# 22158  Abbotsford      801/1 Acacia Pl      1    u   415000.0      S
# 21637  Abbotsford   1/29 Yarra Bank Ct      3    u  1001000.0      S
# ...           ...                  ...    ...  ...        ...    ...
# 10942  Yarraville  347 Williamstown Rd      3    h   781500.0      S
# 10948  Yarraville       198 Francis St      4    h   925000.0      S
# 34856  Yarraville     3 Tarrengower St      2    h  1020000.0     PI
# 23088     croydon           81 hull Rd      3    h   730000.0      S
# 26549    viewbank         1/95 lyon Rd      3    t   885000.0     SP
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# ...

# %%
df["Price"].plot(title= "Prices of house")
# Out:
# <Axes: title={'center': 'Prices of house'}>
